# %%
import re
import requests
from urllib.parse import urlsplit
from collections import deque
from bs4 import BeautifulSoup
import pandas as pd


original_url = input("https://www.geeksforgeeks.org/") 

unscraped = deque([original_url])  

scraped = set()  

emails = set()  

while len(unscraped):
    url = unscraped.popleft()  
    scraped.add(url)

    parts = urlsplit(url)
        
    base_url = "{0.scheme}://{0.netloc}".format(parts)
    if '/' in parts.path:
      path = url[:url.rfind('/')+1]
    else:
      path = url

    print("Crawling URL %s" % url)
    try:
        response = requests.get(url)
    except (requests.exceptions.MissingSchema, requests.exceptions.ConnectionError):
        continue

    new_emails = set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.com", response.text, re.I))
    emails.update(new_emails) 

    soup = BeautifulSoup(response.text, 'lxml')

    for anchor in soup.find_all("a"):
      if "href" in anchor.attrs:
        link = anchor.attrs["href"]
      else:
        link = ''

        if link.startswith('/'):
            link = base_url + link
        
        elif not link.startswith('http'):
            link = path + link

        if not link.endswith(".gz"):
          if not link in unscraped and not link in scraped:
              unscraped.append(link)
df = pd.DataFrame(emails, columns=["Email"])
print(df)
df.to_csv('email.csv', index=False)
# Out:
# https://www.geeksforgeeks.org/feedback@geeksforgeeks.org
# Crawling URL feedback@geeksforgeeks.org
# Empty DataFrame
# Columns: [Email]
# Index: []

# %%
import re
import requests
import requests.exceptions
from urllib.parse import urlsplit
from collections import deque
from bs4 import BeautifulSoup


starting_url = 'http://www.miet.ac.in'

unprocessed_urls = deque([starting_url])

processed_urls = set()


emails = set()

while len(unprocessed_urls):

    url = unprocessed_urls.popleft()
    processed_urls.add(url)

    parts = urlsplit(url)
    base_url = "{0.scheme}://{0.netloc}".format(parts)
    path = url[:url.rfind('/')+1] if '/' in parts.path else url

    print("Crawling URL %s" % url)
    try:
        response = requests.get(url)
    except (requests.exceptions.MissingSchema, requests.exceptions.ConnectionError):

        continue

    
    new_emails = set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", response.text, re.I))
    emails.update(new_emails)
    print(emails)

    soup = BeautifulSoup(response.text, 'lxml')

    for anchor in soup.find_all("a"):
        
        link = anchor.attrs["href"] if "href" in anchor.attrs else ''
        
        if link.startswith('/'):
            link = base_url + link
        elif not link.startswith('http'):
            link = path + link
        
        if not link in unprocessed_urls and not link in processed_urls:
            unprocessed_urls.append(link)
# Out:
# Crawling URL http://www.miet.ac.in
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL http://tour-india.ml/miet-meerut.cf
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL https://miet.ac.in/online-registration
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL https://miet.ac.in/
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL http://www.miet.ac.in#
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL https://miet.ac.in/background
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL https://miet.ac.in/vision-mission
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL https://miet.ac.in/chairman
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL https://miet.ac.in/vice-chairman
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL https://miet.ac.in/director-general
# {'ICBDCI-2020@MIET.pdf', 'contact@miet.ac.in'}
# Crawling URL https://miet.ac.in/executive-director
# ...

# %%
import json
from ibm_watson import VisualRecognitionV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

# %%
#IBM WATSON VISUAL TOOL

authenticator = IAMAuthenticator('dpZ1Ow9pCm1gdsXsAOgu1tEzWab-E0QBWPJPCp83H200')
visual_recognition = VisualRecognitionV3(
    version='2018-03-19',
    authenticator=authenticator
)

visual_recognition.set_service_url('https://api.us-south.visual-recognition.watson.cloud.ibm.com/instances/a291a876-640d-43a3-8401-8b07e6a85d44')

url = 'https://www.biography.com/.image/ar_1:1%2Cc_fill%2Ccs_srgb%2Cg_face%2Cq_auto:good%2Cw_300/MTE4MDAzNDEwNzg5ODI4MTEw/barack-obama-12782369-1-402.jpg'

classes_result = visual_recognition.classify(url=url).get_result()
print(json.dumps(classes_result, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "default",
#           "name": "default",
#           "classes": [
#             {
#               "class": "President of the United States",
#               "score": 0.548,
#               "type_hierarchy": "/person/President of the United States"
#             },
#             {
#               "class": "person",
#               "score": 0.785
#             },
#             {
#               "class": "official",
#               "score": 0.534,
#               "type_hierarchy": "/person/official"
#             },
#             {
#               "class": "adult person",
#               "score": 0.531,
#               "type_hierarchy": "/person/adult person"
#             },
#             {
#               "class": "people",
#               "score": 0.513,
#               "type_hierarchy": "/person/people"
#             },
#             {
#               "class": "politician",
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

google_crawler = GoogleImageCrawler(storage={'root_dir':'images/google'})

google_crawler.crawl(keyword='Suresh jha', max_num=10)

# %%
from icrawler.builtin import GoogleImageCrawler
from six.moves.urllib.parse import urlparse
from icrawler import ImageDownloader
import base64
class MyImageDownloader(ImageDownloader):

    def get_filename(self, task, default_ext):
        
        url_path = urlparse(task['file_url'])[2]

        if '.' in url_path:
            extension = url_path.split('.')[-1]
            if extension.lower() not in [
                    'jpg', 'jpeg', 'png', 'bmp', 'tiff', 'gif', 'ppm', 'pgm'
            ]:
                extension = default_ext
        else:
            extension = default_ext
        # works for python3
        filename = base64.b64encode(url_path.encode()).decode()
        return '{}.{}'.format(filename, extension)


google_crawler = GoogleImageCrawler(
    feeder_threads=1,
    parser_threads=2,
    downloader_threads=4,
    downloader_cls=MyImageDownloader,
    storage={'root_dir': 'images/google'}
)

google_crawler.crawl(keyword='Jefin Francis',  max_num=10, file_idx_offset=0)
# Out:
# 2020-01-25 17:33:39,080 - INFO - icrawler.crawler - start crawling...
# 2020-01-25 17:33:39,096 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-01-25 17:33:39,096 - INFO - feeder - thread feeder-001 exit
# 2020-01-25 17:33:39,096 - INFO - icrawler.crawler - starting 2 parser threads...
# 2020-01-25 17:33:39,112 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2020-01-25 17:33:39,987 - INFO - parser - parsing result page https://www.google.com/search?q=Jefin+Francis&ijn=0&start=0&tbs=&tbm=isch
# 2020-01-25 17:33:40,096 - INFO - downloader - skip downloading file L2Rtcy9pbWFnZS9DNTEwM0FRRlJPX09NNUVLZi1BL3Byb2ZpbGUtZGlzcGxheXBob3RvLXNocmlua18yMDBfMjAwLzA=.jpg
# 2020-01-25 17:33:40,112 - INFO - downloader - skip downloading file LzI4MHgyODBfUlMvMDAvODUvOTcvMDA4NTk3MDcxMDM2YzgyZTFjYmM0ZTNiZDA4ODU2MzEuanBn.jpg
# ...

# %%
from icrawler.builtin import GreedyImageCrawler

greedy_crawler = GreedyImageCrawler(storage={'root_dir': 'images/greedy'})
greedy_crawler.crawl(domains='https://www.flipkart.com/', max_num=10,
                     min_size=None, max_size=None)
# Out:
# 2020-01-25 09:27:47,692 - INFO - icrawler.crawler - start crawling...
# 2020-01-25 09:27:47,692 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-01-25 09:27:47,692 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-01-25 09:27:47,708 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-01-25 09:27:48,567 - INFO - parser - parsing result page https://www.flipkart.com
# 2020-01-25 09:27:48,895 - INFO - downloader - image #1	http://img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png
# 2020-01-25 09:27:48,958 - INFO - downloader - image #2	http://img1a.flixcart.com/www/linchpin/fk-cp-zion/img/plus_b13a8b.png
# 2020-01-25 09:27:49,271 - INFO - downloader - image #3	https://rukminim1.flixcart.com/flap/50/50/image/adf743b56a9538a0.jpg?q=50
# 2020-01-25 09:27:49,317 - INFO - downloader - image #4	https://rukminim1.flixcart.com/flap/844/140/image/2c690c3abf1088af.jpg?q=50
# ...

# %%
#DECODING
filename = base64.b64decode("L2Rtcy9pbWFnZS9DNEQwM0FRR3VzM0tYbFlXaGxRL3Byb2ZpbGUtZGlzcGxheXBob3RvLXNocmlua18yMDBfMjAwLzA=")
print(filename)
# Out:
# b'/dms/image/C4D03AQGus3KXlYWhlQ/profile-displayphoto-shrink_200_200/0'

# %%
import urllib.request

user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

url = "http://spankbang.com/"
headers={'User-Agent':user_agent,} 

request=urllib.request.Request(url,None,headers) #The assembled request
response = urllib.request.urlopen(request)
data = response.read() # The data u need
print(data)
# Out:
# b'\n<!DOCTYPE html>\n<html itemscope="" itemtype="https://schema.org/WebPage" lang="en">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<title>SpankBang: Free Porn Videos and 4K Sex Movies</title>\n<meta name="description" content="SpankBang is the hottest free porn site in the world! Cum like never before and explore millions of fresh and free porn videos! Get lit on SpankBang!" />\n<meta name="keywords" content="porn, xxx, streaming porn, HD porn, HD adult videos, HD pussy videos, sex movies, SpankBang" />\n<meta property="og:title" content="SpankBang: Free Porn Videos and 4K Sex Movies" />\n<meta property="og:image" content="https://spankbang.com/static_desktop/Images/icons/apple-touch-icon-180x180.png" />\n<meta property="og:url" content="https://spankbang.com/" />\n<meta property="og:description" content="SpankBang is the hottest free porn site in the world! Cum like never before and explore millions of fresh and free porn videos! Get lit on Span
# ...

# %%
#SPANKBANG

import requests 
from bs4 import BeautifulSoup 
  
URL = "https://spankbang.com/users/auth?ajax=1&register=1&_=1582948053244"
# r = requests.get(URL) 
  
#soup = BeautifulSoup(r.content, 'html5lib') 
# print(soup.prettify()) 

client = requests.session()

# Retrieve the CSRF token first

a = client.get(URL)  # sets cookie


soup = BeautifulSoup(a.content, 'html5lib') 

table = soup.find('input', attrs = {'id':'csrf_token'})

print(table['value'])

cookie_list = ['__cfduid','backend_version','sb_session',]

# print(dir(client))

# print(client.headers)



cookie = {}

for i in range(3):
    cookie[cookie_list[i]]= client.cookies[cookie_list[i]]
  
print(cookie)

myobj = {"r_username":"abcd",
         "r_password":"123456",
         "r_email":"abc@gmail.com",
         "r_source":"header",
         "csrf_token":table['value']
        }
# cookie = { 
#     "__cfduid":"dd90c9febde3d6f9d4d925c33fcb90ea91582944997",
#     "ana_sid":"f49b0b60743bf978ddb0b75540a6aac63f2cce13b90d8f1d6cf7d1eb5836c1a2",
#     "ana_vid":"f49b0b60743bf978ddb0b75540a6aac63f2cce13b90d8f1d6cf7d1eb5836c1a2",
#     "backend_version":"master",
#     "sb_session":".eJwljEEOQDAQAP-yZwdVuuoHLr4gym4iYiu1DiL-ronjTDLzwHhQ2ichUeg0XVTAHC_RdEMH_QAZz8Sjxo0kG1f6FutpKdE2FIids21tAmPw2DCyrcxsfTC5o2XVNcq_eT8IUyAr.XlnvwQ.uu1DwdEbIf2hjD_KL1CoHgS-YCM"
# }
x = requests.post(URL, data = myobj,cookies = cookie)
print(x.text)
# Out:
# ImJhZTFiNmFkZDZjN2UxZDJiYmNjMTI1NzUzMTllZjlkZTI1Y2FkMmIi.Xln9RQ.NczqYwq0ExSQmo0-cLApZQg0CnI
# {'__cfduid': 'dd56a546ead2d9b88fb2857483c7519b81582955844', 'backend_version': 'master', 'sb_session': '.eJwljEEKgzAQRe8yazdJiWJu0E2vIMnMF4I4kXRciHj3Brp8D967aTnQ9qRQo2jtxEBcT7V2UaT3hzp-27pY3aDd5ASXxyQy8gQnPmdm58MUXm7GOgt84NR17yDFStX_5vkBSbUhtw.Xln9RQ.moIu0857nBw2chKSPdVAIY15U7o'}
#
# <div class="form-holder">
# <ul class="features">
# <li class="logo"><img src="//assets.sb-cd.com/static_desktop/Images/logo_desktop@2xv2.png" /></li>
# <li class="head">Unleash your desires!</li>
# <li><svg class="i_svg i_check-square"><use xlink:href="#check-square"></use></svg> Direct video downloads</li>
# <li><svg class="i_svg i_check-square"><use xlink:href="#check-square"></use></svg> 4k playback</li>
# <li><svg class="i_svg i_check-square"><use xlink:href="#check-square"></use></svg> Upload and share videos</li>
# ...
